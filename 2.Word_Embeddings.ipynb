# %% [markdown]
# # Load libraries

# %% [markdown]
# We are using Pytorch for the extracting word embeddings part. We leverage transformers - the pytorch interface for BERT by Hugging Face.
#
# If you're running this code on Google Colab, you will have to install transformers library each time you reconnect.

# %%
# !pip install pytorch-pretrained-bert
# !pip install transformers
import torch
#from pytorch_pretrained_bert import BertModel, BertForMaskedLM
from transformers import BertModel, BertTokenizer

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import logging
#logging.basicConfig(level=logging.INFO)
import os
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/cd/38/c9527aa055241c66c4d785381eaf6f80a28c224cae97daa1f8b183b5fabb/transformers-2.9.0-py3-none-any.whl (635kB)
#      |████████████████████████████████| 645kB 3.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/3b/88/49e772d686088e1278766ad68a463513642a2a877487decbd691dec02955/sentencepiece-0.1.90-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 13.4MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 13.6MB/s
# Collecting tokenizers==0.7.0
#   Downloading https://files.pythonhosted.org/packages/14/e5/a26eb4716523808bb0a799fcfdceb6ebf77a18169d9591b2f46a9adb87d9/tokenizers-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 8.2MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=f60fa1a05dd5d64979f156c496c2173843a43a0b50b713faa3a703afd17c062a
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.90 tokenizers-0.7.0 transformers-2.9.0

# %% [markdown]
# # Load the model

# %% [markdown]
# First, we mount the Google drive so that we can access the model stored in Google Drive directory.

# %%
# Mount Google Drive to this Notebook instance.
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Setting path variables:

# %% [markdown]
# We pre-trained the model and saved the tf checkpoint. Now we are going to use pytorch. Pytorch can not load a model stored with tf checkpoint.
#
# We have to first convert the tf checkpoint to pytorch model.
#
# my_dir is the Google Drive directory where you have stored your tf checkpoint with config file and vocab.txt.
# bert_model_ckpt is the checkpoint
# bert_model_config_file is the config file
#
# Set BUILD_PYTORCH_MODEL = False if you have pytorch model stored in your Google Drive directory
#
# We then import the pretrained BERT model, and a tokenizer from Google drive directory.

# %%
# Main Directory for the project
my_dir = "___" 

# Setting path to save Bert model
bert_model_dir = os.path.join(my_dir, '<folder_where_bert_model_is>')
bert_model_ckpt = 'xxx.ckpt'
bert_model_config_file = 'config.json'        # Should be always config.json.

# Directory where all the file are kept for processing.
text_file_path = os.path.join(my_dir, 'Sample_Data_2')

# Path where ouput can be stored.
save_dir = os.path.join(my_dir, "Outputs")
# os.mkdir(save_dir)      # if the directory doesn't exist.
output_file_name = "output_300_cluster_200_iter.csv"

# %%
import os
import shutil

BUILD_PYTORCH_MODEL = False #@param {type:"boolean"}

if BUILD_PYTORCH_MODEL:
  
  cur_dir = os.getcwd()
  os.mkdir('PyTorch_Model_Build')
  os.chdir('PyTorch_Model_Build')
  os.system('git clone https://github.com/huggingface/transformers')
  os.chdir("transformers")

  cmd = "transformers-cli convert --model_type bert --tf_checkpoint '{}' --config '{}' --pytorch_dump_output '{}'".format(
      os.path.join(bert_model_dir, bert_model_ckpt), 
      os.path.join(bert_model_dir, bert_model_config_file),
      os.path.join(bert_model_dir, 'pytorch_model.bin')
      )
  out_print = os.system(cmd)
  print(out_print)
  os.chdir(cur_dir)
  shutil.rmtree('PyTorch_Model_Build')

# Load a trained model and vocabulary that you have fine-tuned
model = BertModel.from_pretrained(bert_model_dir)
tokenizer = BertTokenizer.from_pretrained(bert_model_dir)

# %% [markdown]
# BERT tokenizer stores a dictonary that maps the tokens in vocab.txt to the line number for those words in vocab.txt. This dictionary can be accessed by calling tokenizer.vocab
#
# In tokenizer.vocab, key are the tokens and the values are their line number
#
# We store a dictionary where keys are the line numbers and the values are the tokens at those line numbers.

# %%
vocab_dict = dict([(value, key) for key, value in tokenizer.vocab.items()])

# %% [markdown]
# We store all the wiki words from vocab.txt in a set

# %%
wiki_vocab_words = set()
for word in tokenizer.get_vocab():
  if word.startswith("wiki") and word is not "wikipedia":
    wiki_vocab_words.add(word.lower())

print(wiki_vocab_words)
# Out:
# {'wikiaccountancyzsqe', 'wikihomeworkezbsfb', 'wikiemailqlea', 'wikistemfieldsefelbbe', 'wikiworkexperienceiiifloe', 'wikifascismiiosf', 'wikiwikiezasi', 'wikisakezasoo', 'wikilaptopiqasaf', 'wikisocialmediasaqllfz', 'wikisocialscienceszblai', 'wikisexismzlibs', 'wikinonprofitorganizationlzfal', 'wikielectricalengineeringqsei', 'wikiwhitelistiazebq', 'wikiundergraduateeducationzilzaq', 'wikiprofessoriblaoo', 'wikidoctorofphilosophyalls', 'wikigraphicsinterchangeformatizloz', 'wikiunitedstatesefeflso', 'wikidudeeesleq', 'wikiempathyeozeiq', 'wikidirectimagefunctoreozzlff', 'wikicomputerscienceseze', 'wikicapitalismsfib', 'wikirussiazseqi', 'wikiunemploymenteilfi', 'wikitenureeifqsi', 'wikiaccountabilityibiqle', 'wikiblogeebfs', 'wikifeminismiiias', 'wikiwikipediasofelef', 'wikiliberalartsiablf', 'wikipoliticalsciencezfeaa', 'wikirhetoriczsffl', 'wikiivyleagueifqls', 'wikipermalinkalaqzb', 'wikistandardizedtestzzsqli', 'wikilolzaaelq', 'wikijournalismisqza', 'wikisyllabusiqllzas', 'wikiseminarbllooo', 'wikiinternzqazzi', 'wikibullshitfofaf', 'wikimarxismiqofose', 'wikieuropeqzeq', 'wikiharvarduniversityiafzbsoi', 'wikiredditeazqoos', 'wikiyoutubeeszflbb', 'wikimathematicsiaaei', 'wikistudentsunionsiqqoi', 'wikiphpzfiei', 'wikihumanitiesseiez', 'wikistudentfinancialaidiiloqaa', 'wikiportablenetworkgraphicszfeob', 'wikibiologyqizlbez', 'wikifineartqoeil', 'wikigenderstudiessaafq', 'wikistudentloanfbfqqo', 'wikijpegibooq', 'wikiacademictermsfssll', 'wikigraduateschoolefbbza', 'wikiidiotisoof', 'wikiworkingtimessziba', 'wikipodcastioeffse', 'wikicurriculumflqqae', 'wikibarackobamasefebb', 'wikifucksslslzz', 'wikiwowrecordingibfzoss', 'wikitutorzqqqbs', 'wikiliberalartscollegeiabiz', 'wikiartsintegrationqqebfel', 'wikisieaq', 'wikiideologylsfbq', 'wikitheresioisibsz', 'wikiacademicsenateezieiiq', 'wikielectroniclearninglfbll', 'wikitwitterqqaaial', 'wikihypertexttransferprotocoloversecuresocketlayeriesab', 'wikistudyabroadiabeiff', 'wikishiteazzi', 'wikiyaleuniversityefzle', 'wikimechanicalengineeringiqsza', 'wikiliteracyiafsb', 'wikidonaldtrumpfafazlz', 'wikicarnegiemellonuniversityfaoqe', 'wikiinterdisciplinarityiszoi', 'wikichemistrysiao', 'wikistateschoolsleqee', 'wikitextbookzsfioa', 'wikinaturalscienceeaaqo', 'wikiuniversityeilqf', 'wikilaboureconomicsiaila', 'wikicaliforniasfol', 'wikidissertationeoozis', 'wikicriticalthinkingzlbalz', 'wikifacebooklszqela', 'wikiessayioelf', 'wikischolarshipiaoeel', 'wikituitionzfqezo'}

# %% [markdown]
# #Retrieve Embeddings

# %%
# !pip install nltk         # install required if package not present
import nltk
nltk.download('punkt')      # Download required for utilizing punkt tokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Function to identify the wiki words in a sentence.
# * We have to identify if the wikiword is present in the dictionary or not.
# * If the wikiword is present in the dictionary, then it is processed to remove brackets and lower case.
# * If the wiki words is not present then it is broken into its original english words and a mapping is maintained.

# %%
import re
def de_wikify_non_selected(sent, tokenizer_vocab):

  dewikified_words = {}
  wiki_vocab_map = {}
  wiki_words_from_sent = re.findall(r"[wW][iI][kK][iI]_\w+", sent)   # words : [wiki_life_of_pie_cdde, wiki_facebook_ppl]
  # print(wiki_words_from_sent)

  for word in wiki_words_from_sent:                     # mod_words : [wikilifeofpiecdde, wikifacebookppl]
    
    modified_wiki_word = word.replace("_", "")

    if modified_wiki_word.lower() in tokenizer_vocab:
      new_wiki_word = modified_wiki_word.lower()            # modify wikification
      wiki_vocab_map[new_wiki_word] = word

    else:
      word_r = re.sub("_+", "_", word)
      new_wiki_word = " ".join(word_r.split("_")[1:-1])  # de-wikify - wiki__life_of_pie__ccdde -> life of pie
      dewikified_words[word] = new_wiki_word.split()   # Save tokens {"wiki_life_of_pie_ccdde" : ['life', 'of','pie']}
    
    sent = sent.replace(word, new_wiki_word)       

  return sent, dewikified_words, wiki_vocab_map, len(wiki_words_from_sent)

# %% [markdown]
# *   Code to sample test function : de_wikify_non_selected(sent, wiki_vocab_words)

# %%
sent = "gt go get a  Wiki__Liberal_arts__iablf  degree n ht s i imgur"
print(de_wikify_non_selected(sent, wiki_vocab_words))
re.findall(r"wiki_\w+", sent.lower())
# Out:
# ('gt go get a  wikiliberalartsiablf  degree n ht s i imgur', {}, {'wikiliberalartsiablf': 'Wiki__Liberal_arts__iablf'}, 1)
# ['wiki__liberal_arts__iablf']

# %% [markdown]
# BERT expects input in specific format. [CLS] token marks the start of the sentence and [SEP] token marks the end of the sentence. For example, say we want to pass ‘This is my test sentence.’ As an input to get the word embeddings. The expected input in this case will be [CLS] This is my test sentence. [SEP]
#
# We passed one sentence at a time to the BERT model. The BERT tokenizer tries to convert the input sentence into different tokens. Initially, the input sentence is split on whitespaces giving the tokenizer all the words in the sentence. The aim of the tokenizer is to keep the all the words intact. Hence, the BERT tokenizer will try to map every word it finds in input to some token defined in vocab.txt. If it doesn’t find a token to map for any word, it will break down the word into smaller tokens. For example, vocab.txt doesn’t contain the word ‘embeddings’. Hence, the tokenizer splits the word embeddings into four different tokens [‘em’, ‘##bed’, ‘##ding’, ‘##s’] so that it retains some contextual meaning of the word.
#
# BERT is trained on sentence pairs and it expects sentence pairs as an input. We usually distinguish between sentences in sentence pairs using 1s and 0s. In our case, we will always pass one sentence at a time. Hence, we create a vector of length same as the length of sentence tokens having all 1s. We pass this vector as segment IDs.
#
# We get full set of hidden states as an output when we pass token IDs and segment IDs to the BERT model. This object has four dimensions, in the following order:
# - The layer number (12 layers)
# - The batch number (1 sentence)
# - The token number (number of tokens in our sentence)
# - The hidden units (768 features)
#
# We further get rid of the batches dimension as batch number is always 1.
# Now, every token is represented by 12 layers and every layer has 768 hidden units. We add up last four layers to create word vector for any particular token. Word vector of every word is a now an array of 768 items. In other words, we have every token represented in a 768-dimentional space.
#
# For all the important lines the comments are added in the cell below.

# %%
def get_sentence_word_vetors(sentence, tokenizer):

  input_ids = []
  sent_word_vectors = []
  encoded_dict = tokenizer.encode_plus(
                  sentence,                      # Sentence to encode.
                  add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                  max_length = 512,           # Pad & truncate all sentences.
                  pad_to_max_length = True,
                  return_attention_mask = True,   # Construct attn. masks.
                  return_tensors = 'pt',     # Return pytorch tensors.
              )

  input_ids.append(encoded_dict['input_ids'])
  tokens_tensor = torch.cat(input_ids, dim=0)


  # Mark each of the 512 tokens as belonging to sentence "1".
  segments_ids = [1] * 512



  # Convert inputs to PyTorch tensors
  #tokens_tensor = torch.tensor([indexed_tokens])
  segments_tensors = torch.tensor([segments_ids])

  # Put the model in "evaluation" mode, meaning feed-forward operation.
  model.eval()

  # Predict hidden states features for each layer
  with torch.no_grad():
      encoded_layers, _ = model(tokens_tensor, segments_tensors)
    
  # Concatenate the tensors for all layers. We use `stack` here to
  # create a new dimension in the tensor.
  #token_embeddings = torch.stack(encoded_layers, dim=0)
  token_embeddings = encoded_layers
  # token_embeddings.size()

  # Remove dimension 1, the "batches".
  token_embeddings = torch.squeeze(token_embeddings, dim=1)

  # Swap dimensions 0 and 1.
  token_embeddings = token_embeddings.permute(1,0,2)


  # Stores the token vectors, with shape [512 x 768]
  token_vecs_sum = []
  # For each token in the sentence...
  for token in token_embeddings:

      # Sum the vectors from the last four layers.
      sum_vec = torch.sum(token[-4:], dim=0)
      
      # Use `sum_vec` to represent `token`.
      token_vecs_sum.append(sum_vec)

  # print ('Shape is: %d x %d' % (len(token_vecs_sum), len(token_vecs_sum[0])))

  for i in range(512):
    tok = (((encoded_dict['input_ids'])[0])[i]).item()
    
    vocab_word = vocab_dict[tok] 
    word_vector = token_vecs_sum[i]
    sent_word_vectors.append([vocab_word, word_vector]) # [["i", vec1], ["love", vec2], ["wikifacebook", vec3]]

  return sent_word_vectors

# %% [markdown]
# Processing Sentences which are in the form of an array:
# Simply removing the brackets and each string in one enclosed bracket is treated as a separate sentence

# %%
def process_arrays(data):
  return [sent.replace("[", "").replace("]","").strip() for sent in data.split("][")]

# %% [markdown]
# A quick sample test to check the word embedding on words with different meanings in different context.

# %%
import numpy as np
sent = "After stealing money from the bank vault, the bank robber was seen fishing on the Mississippi river bank."

sent_word_vecs = get_sentence_word_vetors(sent, tokenizer)

# for i, word in enumerate(sent_word_vecs):
#   print(i, word[0])

bank1 = sent_word_vecs[6][1].data.numpy()
bank2 = sent_word_vecs[10][1].data.numpy()
bank3 = sent_word_vecs[24][1].data.numpy()

def cos_sim(a,b):
  return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))

print(cos_sim(bank1, bank2))

print(cos_sim(bank1, bank3))
print(cos_sim(bank2, bank3))
# Out:
# 0.8307625
# 0.7632531
# 0.75604004

# %% [markdown]
# Function for processing data :
#
#
# *   All the text files which need to be processed are expected to be kept in one directory.
# *   Path of the directory - txt_file_path
# *   Each file data is extracted and sentences are separated:
# >*  For normal text we are using nltk tokeniser.
# >*  For text files containing brackets [], each string in enclosed brackets is a sentence.
#
# *   Embeddings for all the words in a sentence are extracted, however only the wikiwords embeddings are stored from each document.
# *   If sentence has no wikiword then it is not processed at all.

# %%
import glob
from nltk.tokenize import sent_tokenize
import re


# Running embedding extraction on all the files kept in - text_file_path
files = glob.glob(text_file_path + os.sep + '/*.txt')
doc_num = 0

selected_word_vectors = []

for name in files:
  name_after_split = name.split('/')
  doc_name = name_after_split[len(name_after_split) -1]       # Maintaining document name
  doc_num += 1

  print("Running document : ", doc_name)  

  with open(name, encoding="utf-8") as f:
    
    count = 0
    for text in f:
      
      if re.search("\]\s*\[", text):                    # Check if file contains brackets
        sents = process_arrays(text)
      else:
        sents = sent_tokenize(text)                     # or normal sentences
      
      dewikified_words = {}
      
      for line in sents:
        
        print(line)
        
        mod_line, dewikified_words, wiki_vocab_map, wiki_count = de_wikify_non_selected(line, wiki_vocab_words)

        if wiki_count == 0:
          continue
        
        print("Processing line : ", mod_line)

        sent_word_vetors = get_sentence_word_vetors(mod_line, tokenizer)


        # After extracting word embeddings, we are storing only the wikiwords embeddings

        for word, vec in sent_word_vetors:
          if word.lower() in wiki_vocab_words:
            selected_word_vectors.append([doc_name, wiki_vocab_map[word.lower()], vec])

        # Reconstructing the embeddings for the wikiwords which were not among the top 100 selected.
        # Averaging the Embeddings of the individual english words belonging to a wikiword.
        # If the individual english word is also broken in bert tokenisation then the embedding is not stored.
        for key in dewikified_words:

          print(key)

          dewiki_vector = []
          dewiki_index = -1
          for word, vec in sent_word_vetors:

            if word.lower() == dewikified_words[key][dewiki_index+1].lower():   # {"wiki_life_of_pie_ccdde" : ['life', 'of','pie']}
              dewiki_vector.append(vec)
              dewiki_index += 1
            else:
              dewiki_index = -1
              dewiki_vector = []

            if dewiki_index >= len(dewikified_words[key]) - 1:
              avg_vec = torch.mean(torch.stack(dewiki_vector), dim=0)
              selected_word_vectors.append([doc_name, key, avg_vec])
              dewiki_index = -1
              dewiki_vector = []
# Out:
# Running document :  politics-all-subreddits-2017-12-2700.txt
# butler county just swung by points towards jones granted it is a small county but still
# what i am noticing is that even in counties moore is winning hes consistently down percent or more from the election if the urban centers have strong turn outs that could be enough
# no doubt there but it is feasible hes basically running against the least palatable republican unless they reanimated adolf hitler and its still a close race
# ba dum tish
# too many people who call themselves religious miss the point of it they consider church and  Wiki__Righteousness__zqofel  to be the price you have to pay to be saved thats completely missing the point i may be catholic but im not draconian jewish muslim  Wiki__Atheism__iszflsfz  it doesnt matter to me my belief is that if you are a good and just person then god will not turn his back on you i mean if im being honest you might spend some time in  Wiki__Purgatory__ifleleio  for not recognizing the messiah but  Wiki__Purgatory__ifleleio  isnt a bad thing and i fully expect all of us to wind up there in some form or another its just the waiting room every soul needs scrubbing after all
# Processing line :  too many people who call themselves religious miss the point of it they consider church and  Righteousness  to be the price you have to pay to be saved thats completely missing the point i may be catholic but im not draconian jewish muslim  Atheism  it doesnt matter to me my belief is that if you are a good and just person then god will not turn his back on you i mean if im being honest you might spend some time in  Purgatory  for not recognizing the messiah but  Purgatory  isnt a bad thing and i fully expect all of us to wind up there in some form or another its just the waiting room every soul needs scrubbing after all
# Wiki__Righteousness__zqofel
# Wiki__Atheism__iszflsfz
# Wiki__Purgatory__ifleleio
# hey the  Wiki__Idiot__isoof  did something right
# Processing line :  hey the  wikiidiotisoof  did something right
# literacy test ballots
# its too goddamn early call anything but call me at least encouraged
# etowah county percent white is said to be jones moore uhhh that cant be right
# weird i missed where hillary clinton beat trump in alabama due to her lifelong faith compared to trump u s lifelong avoidance of anything pious whatsoever i think it is even simpler u cabortion is murder u d is all you have to say
# if i didnt know that this wasnt a snl sketch id think it was one
# i e making her entire platform as shes obviously gearing up for solely about being a woman
# doesnt it all come out about the same once you figure in the cost of living personally i think everybody is being screwed but yeah id for sure rather live in maryland than alabama just based off the hookworm
# thats false the allegations against clinton were never as credible as those against roy moore seriously read about them if you arent sure
# wow sarah huckabees constant lying is really taking a toll on her face you can tell that shes really having a problem with it shes too young to have to go through this lying for a wannabe dictator is something no young person should ever have to endure
# gt why would alabama ever vote for a democrat after you guys have called them inbred  Wiki__Redneck__iaooblqz  for the past years liberal  Wiki__Delusion__izszqb  are truly the funniest thing in the world sorry son republicans are the ones who have been calling them rednecks this whole time unless you think the rich folks in ivory towers are all democrats
# Processing line :  gt why would alabama ever vote for a democrat after you guys have called them inbred  Redneck  for the past years liberal  Delusion  are truly the funniest thing in the world sorry son republicans are the ones who have been calling them rednecks this whole time unless you think the rich folks in ivory towers are all democrats
# Wiki__Redneck__iaooblqz
# Wiki__Delusion__izszqb
# not surprising i remember seeing someone on  Wiki__Facebook__lszqela  sticking up for josh duggar by saying that sexually abusing his sisters is no big deal because stuff like that happens in every family
# Processing line :  not surprising i remember seeing someone on  wikifacebooklszqela  sticking up for josh duggar by saying that sexually abusing his sisters is no big deal because stuff like that happens in every family
# something like ill be dating you in years to a preteen girl commenting about infant tiffanys thighs and tits in an interview when asked what he has in common with ivanka she said golf or real estate he said sex n this fucked up  Wiki__Photo_shoot__ioeqbbal  ht s pmchollywoodlife files wordpress com donald ivanka trump throwback photo ftr jpg w=
# Processing line :  something like ill be dating you in years to a preteen girl commenting about infant tiffanys thighs and tits in an interview when asked what he has in common with ivanka she said golf or real estate he said sex n this fucked up  Photo shoot  ht s pmchollywoodlife files wordpress com donald ivanka trump throwback photo ftr jpg w=
# Wiki__Photo_shoot__ioeqbbal
# idk i heard  Wiki__Barack_Obama__sefebb  has been attacking and killing plentys us citizens around the world with drones
# Processing line :  idk i heard  wikibarackobamasefebb  has been attacking and killing plentys us citizens around the world with drones
# alabama will vote roy moore in just look at their history they dont give a  Wiki__Shit__eazzi  sigh please prove me wrong you did it alabama  Wiki__Fuck__sslslzz  yeah
# Processing line :  alabama will vote roy moore in just look at their history they dont give a  wikishiteazzi  sigh please prove me wrong you did it alabama  wikifucksslslzz  yeah
# with exception to jake tapper i fucking hate  Wiki__CNN__bzoza
# Processing line :  with exception to jake tapper i fucking hate  CNN
# Wiki__CNN__bzoza
# as much as we might want to be nostalgic for those times this should be a wake up call for all of us to be more involved and aware of whats going on in our nation the outcome of a state election on the opposite side of the country could have impacts on your own life just fucking look at where we are now if all of us have paid a lot more attention years ago maybe this all could have been avoided
# fuckin a this is going to be a cheek clencher
# i know you were just searching his comment history by controversial to find dirt but that was literally a  Wiki__Sarcasm__zqsaql  reply to climate change denial
# Processing line :  i know you were just searching his comment history by controversial to find dirt but that was literally a  Sarcasm  reply to climate change denial
# Wiki__Sarcasm__zqsaql
# i bet the obstruction portion is probably very close to being done and maybe they are done with the wh interviews for that obstruction portion of the case they havent even touched them yet on the conspiracy with  Wiki__Russia__zseqi  aspect from what leaks are saying the interviews have been focussed on thats not good news for trump theyre going to get him out of office before they bring the conspiracy election charges
# Processing line :  i bet the obstruction portion is probably very close to being done and maybe they are done with the wh interviews for that obstruction portion of the case they havent even touched them yet on the conspiracy with  wikirussiazseqi  aspect from what leaks are saying the interviews have been focussed on thats not good news for trump theyre going to get him out of office before they bring the conspiracy election charges
# lololololol mueller
# gt u cbruce isn u t some spy hunter u d said a former colleague u che had nothing to do with the  Wiki__Russia__zseqi  investigation he administered grants mostly he was an administrative person u d welp that kills the narrative on plan d to stop the mueller investigation on to plan e trump
# Processing line :  gt u cbruce isn u t some spy hunter u d said a former colleague u che had nothing to do with the  wikirussiazseqi  investigation he administered grants mostly he was an administrative person u d welp that kills the narrative on plan d to stop the mueller investigation on to plan e trump
# trump little fat kim just imported more gas from china wont help despite new sanctions if china wont do something soon we will do not test me rocket boy
# he doesnt know how to do that it will have been stolen from moore if he loses they cant admit failure defeat
# no such thing as  Wiki__Nonviolence__ilalss  Wiki__Nonviolent_resistance__isbzzf  all you accomplish is annoyance
# Processing line :  no such thing as  Nonviolence  Nonviolent resistance  all you accomplish is annoyance
# Wiki__Nonviolence__ilalss
# Wiki__Nonviolent_resistance__isbzzf
# instead unique jokes
# and what have we learned about you
# Wiki__LOL__zaaelq
# Processing line :  wikilolzaaelq
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# no unless your act of pooping makes a poop sound
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# ht s www psychologytoday com  Wiki__Blog__eebfs  your online secrets  Wiki__Troll__Internet___ifsqf  are narcissists  Wiki__Psychopathy__llsefeo  and  Wiki__Sadomasochism__zobebs
# Processing line :  ht s www psychologytoday com  wikiblogeebfs  your online secrets  Troll Internet  are narcissists  Psychopathy  and  Sadomasochism
# Wiki__Troll__Internet___ifsqf
# Wiki__Psychopathy__llsefeo
# Wiki__Sadomasochism__zobebs
# oh my god is he actually an under appreciated poetic genius
# the sad part is i think we do doesnt make us perfect but we are a hell of a lot better than many even the shady practices i was talking about are preferable to most other places ive lived
# what about military  Wiki__Homelessness__ielqf
# Processing line :  what about military  Homelessness
# Wiki__Homelessness__ielqf
# hey you mentioned elsewhere that youre also a vet what was your mos where did you serve
# the bannonism thing is a great point as for caring about the people he hurt i never believed moore would get booted for that reason
# gt all the ballots are put through the machines not knowing the system can a human interfere with that are there methods to prevent having a ballot entered more than once obviously its easy enough if some unique digital code is on each ballot to help notify irregularities missed ballot scan multiple ballot scan anyway the instant you tell me something has been digitized the technician in me says holy hell do not delete that you have any idea how long itd take to replicate it id say save it just on the convenience factor alone considering storage is almost a non issue in recent years
# but but mama said we  Wiki__Hafta__ilqslsil  swear on the buybull
# Processing line :  but but mama said we  Hafta  swear on the buybull
# Wiki__Hafta__ilqslsil
# trump is mentally incapable of allowing a slight perceived or otherwise to go unanswered especially if its by a person of color or a woman
# ugh remember laughing at canada because of rob ford simpler times
# Running document :  the_arts1_2667.txt
# here let me do the hard work for you you delicate flower definition ht s en  Wiki__Wikipedia__sofelef  org  Wiki__Wiki__ezasi  definitions of fascism#marxist definitions right wing fascists are fervently against  Wiki__Marxism__iqofose   Wiki__Socialism__zbafl   Wiki__Anarchism__iz  communism  Wiki__Environmentalism__iabbooq  etc – in essence they are against the progressive left in total including moderate lefts social  Wiki__Democracy__lqsq  etc  Wiki__Fascism__iiosf  is an  Wiki__Far_right__zzizzo   Wiki__Ideology__lsfbq  though it can be opportunistic  Wiki__Nationalism__zilfa   Wiki__Fascism__iiosf  places a very strong emphasis on patriotism and  Wiki__Nationalism__zilfa  criticism of the nations main ideals especially war is lambasted as  Wiki__Patriotism__zfssz  at best and treason at worst  Wiki__Propaganda__zezoe  Wiki__Propaganda__zezoe  consistently broadcasts threats of attack while justifying pre emptive war fascism invariably seeks to instill in its people the warrior mentality to always be vigilant wary of strangers and suspicious of foreigners hierarchy fascist society is ruled by a righteous leader who is supported by an elite secret vanguard of  Wiki__Capitalism__sfib  hierarchy is prevalent throughout all aspects of society – every street every workplace every school will have its local  Wiki__Adolf_Hitler__zleisae  part police informer part bureaucrat – and society is prepared for war at all times the absolute power of the social hierarchy prevails over everything and thus a  Wiki__Totalitarianism__eofeq  Wiki__Totalitarianism__eofeq  society is formed  Wiki__Representative_democracy__szeia  is acceptable only if it can be controlled and regulated  Wiki__Direct_democracy__qsaib  e g communism is the greatest of all crimes any who oppose the social hierarchy of fascism will be imprisoned or executed anti equality fascism loathes the principles of economic equality and disdains equality between immigrant and citizen some forms of  Wiki__Fascism__iiosf  extend the fight against equality into other areas gender  Wiki__Sexual_minority__esazbsf  or religious rights for example religious fascism contains a strong amount of  Wiki__Reactionary__isazzb  religious beliefs harking back to times when religion was strict potent and pure nearly all fascist societies are christian and are supported by catholic and  Wiki__Protestantism__zezfq  churches  Wiki__Capitalism__sfib   Wiki__Fascism__iiosf  does not require revolution to exist in  Wiki__Capitalism__sfib  Wiki__Capitalism__sfib  society fascists can be elected into office though their disdain for elections usually means manipulation of the electoral system they view parliamentary and congressional systems of government to be inefficient and weak and will do their best to minimize its power over their policy agenda fascism exhibits the worst kind of  Wiki__Capitalism__sfib  where corporate power is absolute and all vestiges of workers rights are destroyed war fascism is  Wiki__Capitalism__sfib  at the stage of impotent imperialism war can create markets that would not otherwise exist by wreaking massive devastation on a society which then requires reconstruction fascism can thus liberate the survivors provide huge loans to that society so fascist corporations can begin the process of rebuilding voluntarist ideology fascism adopts a certain kind of “voluntarism ” they believe that an act of will if sufficiently powerful can make something true thus all sorts of ideas about racial inferiority historical destiny even physical science are supported by means of violence in the belief that they can be made true it is this sense that fascism is subjectivist anti modern fascism loathes all kinds of modernism especially creativity in the arts whether acting as a mirror for life where it does not conform to the fascist ideal or expressing deviant or innovative points of view fascism invariably burns books and victimises artists artists who do not promote the fascists ideals a ...
# Processing line :  here let me do the hard work for you you delicate flower definition ht s en  wikiwikipediasofelef  org  wikiwikiezasi  definitions of fascism#marxist definitions right wing fascists are fervently against  wikimarxismiqofose   Socialism   Anarchism  communism  Environmentalism  etc – in essence they are against the progressive left in total including moderate lefts social  Democracy  etc  wikifascismiiosf  is an  Far right   wikiideologylsfbq  though it can be opportunistic  Nationalism   wikifascismiiosf  places a very strong emphasis on patriotism and  Nationalism  criticism of the nations main ideals especially war is lambasted as  Patriotism  at best and treason at worst  Propaganda  Propaganda  consistently broadcasts threats of attack while justifying pre emptive war fascism invariably seeks to instill in its people the warrior mentality to always be vigilant wary of strangers and suspicious of foreigners hierarchy fascist society is ruled by a righteous leader who is supported by an elite secret vanguard of  wikicapitalismsfib  hierarchy is prevalent throughout all aspects of society – every street every workplace every school will have its local  Adolf Hitler  part police informer part bureaucrat – and society is prepared for war at all times the absolute power of the social hierarchy prevails over everything and thus a  Totalitarianism  Totalitarianism  society is formed  Representative democracy  is acceptable only if it can be controlled and regulated  Direct democracy  e g communism is the greatest of all crimes any who oppose the social hierarchy of fascism will be imprisoned or executed anti equality fascism loathes the principles of economic equality and disdains equality between immigrant and citizen some forms of  wikifascismiiosf  extend the fight against equality into other areas gender  Sexual minority  or religious rights for example religious fascism contains a strong amount of  Reactionary  religious beliefs harking back to times when religion was strict potent and pure nearly all fascist societies are christian and are supported by catholic and  Protestantism  churches  wikicapitalismsfib   wikifascismiiosf  does not require revolution to exist in  wikicapitalismsfib  wikicapitalismsfib  society fascists can be elected into office though their disdain for elections usually means manipulation of the electoral system they view parliamentary and congressional systems of government to be inefficient and weak and will do their best to minimize its power over their policy agenda fascism exhibits the worst kind of  wikicapitalismsfib  where corporate power is absolute and all vestiges of workers rights are destroyed war fascism is  wikicapitalismsfib  at the stage of impotent imperialism war can create markets that would not otherwise exist by wreaking massive devastation on a society which then requires reconstruction fascism can thus liberate the survivors provide huge loans to that society so fascist corporations can begin the process of rebuilding voluntarist ideology fascism adopts a certain kind of “voluntarism ” they believe that an act of will if sufficiently powerful can make something true thus all sorts of ideas about racial inferiority historical destiny even physical science are supported by means of violence in the belief that they can be made true it is this sense that fascism is subjectivist anti modern fascism loathes all kinds of modernism especially creativity in the arts whether acting as a mirror for life where it does not conform to the fascist ideal or expressing deviant or innovative points of view fascism invariably burns books and victimises artists artists who do not promote the fascists ideals are seen as “decadent ” fascism is hostile to broad learning and interest in other cultures since such pursuits threaten the dominance of fascist myths the peddling of conspiracy theories is usually substituted for the objective study of history
# Wiki__Socialism__zbafl
# Wiki__Anarchism__iz
# Wiki__Environmentalism__iabbooq
# Wiki__Democracy__lqsq
# Wiki__Far_right__zzizzo
# Wiki__Nationalism__zilfa
# Wiki__Patriotism__zfssz
# Wiki__Propaganda__zezoe
# Wiki__Adolf_Hitler__zleisae
# Wiki__Totalitarianism__eofeq
# Wiki__Representative_democracy__szeia
# Wiki__Direct_democracy__qsaib
# Wiki__Sexual_minority__esazbsf
# Wiki__Reactionary__isazzb
# Wiki__Protestantism__zezfq
# Running document :  education-all-subreddits-2017-07-123.txt
# algebra isnt actually being what is happening is the  Wiki__Algebra__ieqa  is being substituted with a less abstract more practical class
# Processing line :  algebra isnt actually being what is happening is the  Algebra  is being substituted with a less abstract more practical class
# Wiki__Algebra__ieqa
# no most likely is there to ensure the phrase is not a stereotype if i say college students are more likely than year olds to stay up till am i am not stereotyping either group just generalizing habits a stereotype is a specific image of an individual based on a group so if you look at an  Wiki__African_American__zisf  Wiki__United_States__efeflso  girl named donna and assume she will want to wear a headwrap thatd be stereotyping just commenting on how groups function societally is not a stereotype applying it to an individual is
# Processing line :  no most likely is there to ensure the phrase is not a stereotype if i say college students are more likely than year olds to stay up till am i am not stereotyping either group just generalizing habits a stereotype is a specific image of an individual based on a group so if you look at an  African American  wikiunitedstatesefeflso  girl named donna and assume she will want to wear a headwrap thatd be stereotyping just commenting on how groups function societally is not a stereotype applying it to an individual is
# Wiki__African_American__zisf
# a pe  Wiki__Waiver__iozooff  for sports participation is different than a fitness test though and solves that problem when i went to hs we didnt have mandatory pe every year thank god but you could get your year pe elective we had a mandatory  Wiki__Physical_fitness__fezqab  health class that was a hybrid pe health where we dressed out days per week waived with year of sport or multiple sports added up to that amount it could be school based or a certified sport outside of school letter from your coach with practice schedule season info etc
# Processing line :  a pe  Waiver  for sports participation is different than a fitness test though and solves that problem when i went to hs we didnt have mandatory pe every year thank god but you could get your year pe elective we had a mandatory  Physical fitness  health class that was a hybrid pe health where we dressed out days per week waived with year of sport or multiple sports added up to that amount it could be school based or a certified sport outside of school letter from your coach with practice schedule season info etc
# Wiki__Waiver__iozooff
# Wiki__Physical_fitness__fezqab
# incorrect
# theyd have to increase salaries to make a k plan be worth what the pension is there are some portability issues with pensions people who leave the career people who change states but they are better for the vast majority of teachers as the article says as most teachers stay in their state and teach long enough to vest anyway this is just a way for states to pay teachers less granted if it was k and a great match and a pay bump that allows you to get the equivalent of the pension maybe itd be better but thats not what theyre doing gt in fact a k plan would provide percent less retirement income for the typical  Wiki__California__sfol  classroom teacher compared with the current pension which is consistent with  Wiki__Scientific_method__zbaee  in other states including one commissioned by the colorado legislature and another conducted in texas give teachers the equivalent of that percent as part of their salary so they can save it move it etc then fine but this isnt about helping teachers its about saving money by shorting teachers
# Processing line :  theyd have to increase salaries to make a k plan be worth what the pension is there are some portability issues with pensions people who leave the career people who change states but they are better for the vast majority of teachers as the article says as most teachers stay in their state and teach long enough to vest anyway this is just a way for states to pay teachers less granted if it was k and a great match and a pay bump that allows you to get the equivalent of the pension maybe itd be better but thats not what theyre doing gt in fact a k plan would provide percent less retirement income for the typical  wikicaliforniasfol  classroom teacher compared with the current pension which is consistent with  Scientific method  in other states including one commissioned by the colorado legislature and another conducted in texas give teachers the equivalent of that percent as part of their salary so they can save it move it etc then fine but this isnt about helping teachers its about saving money by shorting teachers
# Wiki__Scientific_method__zbaee
# zero tolerance about what though
# im not clear on what precisely this post is trying to say if the implication is supposed to be that education hasnt been an effective program to fight poverty then it is completely wrong the tables showing a flat poverty rate do not compare the situation today with what the situation would have been without the education improvements the unspoken assumption would have to be that if only we hadnt tried to expand education todays economy would look just like the one from years ago but anyone can tell thats ridiculous weve gone through multiple revolutions in our economy in the time since then its also hiding the fact that living at poverty level today is a considerably more comfortable situation than living at poverty level in on the other hand if the article is trying to argue that education is not sufficient as an anti poverty program then yes of course it isnt we still need direct intervention to ensure access to food and housing and child care we still need economic policies to control inequality and we still need to meet the greatest challenge facing us in a world where technology has made it just plain unnecessary unnecessary for everyone to work full time how do we build an economy that doesnt leave the  Wiki__Unemployment__eilfi  living in economic ruin
# Processing line :  im not clear on what precisely this post is trying to say if the implication is supposed to be that education hasnt been an effective program to fight poverty then it is completely wrong the tables showing a flat poverty rate do not compare the situation today with what the situation would have been without the education improvements the unspoken assumption would have to be that if only we hadnt tried to expand education todays economy would look just like the one from years ago but anyone can tell thats ridiculous weve gone through multiple revolutions in our economy in the time since then its also hiding the fact that living at poverty level today is a considerably more comfortable situation than living at poverty level in on the other hand if the article is trying to argue that education is not sufficient as an anti poverty program then yes of course it isnt we still need direct intervention to ensure access to food and housing and child care we still need economic policies to control inequality and we still need to meet the greatest challenge facing us in a world where technology has made it just plain unnecessary unnecessary for everyone to work full time how do we build an economy that doesnt leave the  wikiunemploymenteilfi  living in economic ruin
# imo its clear they made a mistake in asking the question theres no reason they would have intentionally done this given that the question was asked however i think they believe its better to score the question as intended rather than throw it out based on what they see as a technicality they dont believe that the proof that invalidates the question is accessible to a significant number of the students the test was really aimed at among those few to whom the proof was accessible they are likely to have scored extremely well despite the incorrect question so there arent really significant consequences to them for that one possibly wrong answer as much as my emotional response is to be disgusted by this they may be right from a  Wiki__Pragmatism__qsilo  point of view
# Processing line :  imo its clear they made a mistake in asking the question theres no reason they would have intentionally done this given that the question was asked however i think they believe its better to score the question as intended rather than throw it out based on what they see as a technicality they dont believe that the proof that invalidates the question is accessible to a significant number of the students the test was really aimed at among those few to whom the proof was accessible they are likely to have scored extremely well despite the incorrect question so there arent really significant consequences to them for that one possibly wrong answer as much as my emotional response is to be disgusted by this they may be right from a  Pragmatism  point of view
# Wiki__Pragmatism__qsilo
# blatant advertising masquerading as education news if people want to buy their kids an  Wiki__Educational_toy__iboiblb  go for it but this isnt meaningful reflective and thought provoking discourse about educational policy research technology and politics thats what this is for its not a billboard
# Processing line :  blatant advertising masquerading as education news if people want to buy their kids an  Educational toy  go for it but this isnt meaningful reflective and thought provoking discourse about educational policy research technology and politics thats what this is for its not a billboard
# Wiki__Educational_toy__iboiblb
# i know something about san francisco and dc so i can comment there im not familiar with new york or tucson there was recently a lot of attention paid to school choice options in washington dc when research was published about educational outcomes it turns out that when students who wouldnt have been able to afford private schools were given the opportunity via  Wiki__Voucher__zisqoob  programs they managed to perform worse than comparable students in the public school system this is pretty remarkable since peer effects are one of the strongest forces in education outcomes these students got the chance to go to school with motivated and high achieving peers and yet they still performed worse because the schools themselves werent able to meet their needs there was a mix of cultural mismatch language barriers and ineffective esl instruction poor services to address  Wiki__Learning_disability__ioqlooaz  Wiki__Disability__sbzas  or deficiencies in social and  Wiki__Executive_system__laefls  and outright discrimination so if the best schools means the schools that are best for those students no they werent the private or parochial schools they were the neighborhood public schools san francisco has a similar situation the tech industry here has created a stark division between the economic haves and have nots the schools with high test scores are not doing a better job they are just doing an easier job teaching the children of highly paid professionals in  Wiki__Silicon_Valley__zbqlb
# Processing line :  i know something about san francisco and dc so i can comment there im not familiar with new york or tucson there was recently a lot of attention paid to school choice options in washington dc when research was published about educational outcomes it turns out that when students who wouldnt have been able to afford private schools were given the opportunity via  Voucher  programs they managed to perform worse than comparable students in the public school system this is pretty remarkable since peer effects are one of the strongest forces in education outcomes these students got the chance to go to school with motivated and high achieving peers and yet they still performed worse because the schools themselves werent able to meet their needs there was a mix of cultural mismatch language barriers and ineffective esl instruction poor services to address  Learning disability  Disability  or deficiencies in social and  Executive system  and outright discrimination so if the best schools means the schools that are best for those students no they werent the private or parochial schools they were the neighborhood public schools san francisco has a similar situation the tech industry here has created a stark division between the economic haves and have nots the schools with high test scores are not doing a better job they are just doing an easier job teaching the children of highly paid professionals in  Silicon Valley
# Wiki__Voucher__zisqoob
# Wiki__Learning_disability__ioqlooaz
# Wiki__Disability__sbzas
# Wiki__Executive_system__laefls
# Wiki__Silicon_Valley__zbqlb
# the  Wiki__Real_point__aoaaqeq  is a little bit hidden its not legitimate colleges driving these statistics its the collapse of the for profit industry good riddance
# Processing line :  the  Real point  is a little bit hidden its not legitimate colleges driving these statistics its the collapse of the for profit industry good riddance
# Wiki__Real_point__aoaaqeq
# school is already crazy expensive enough nfor many scholarships theres a required gpa that has to be kept while in college or the scholarship goes away anyway this seems unnecessary
# not necessarily while we like to think age means maturity that is not always the case
# im also canadian use a different subreddit
# if you think a school system is bad because it serves children of  Wiki__Single_parent__zzbioq  youre a horrible person
# Processing line :  if you think a school system is bad because it serves children of  Single parent  youre a horrible person
# Wiki__Single_parent__zzbioq
# ht i imgur com wqojhx png
# i graduated in years with a degree in secondary english education i was accepted to the masters program at my university but i put it off for a few years my fear was that i would be teaching kids up to years old and i was only going to be or years old i never started the ma program and never taught make sure you consider your own age and maturity when you start teaching
# there are a few points like dirt displaying exploratory pc movement outlining and acting which energy learners notwithstanding their standard animation courses in  Wiki__Kolkata__flqos  can participate in their  Wiki__Scholasticism__eqalz  time to time the learners would likewise agree to accept classes and workshops by looking at changed unmistakable segment specializes in a similar work range they will moreover get the specific preparing or entry level position program to truly feel the genuine occupation condition of their picked work area a few foundations are moreover giving the situating to the students since they have great tie ups with multinational organizations you ought to likewise check for animation course charges in  Wiki__Kolkata__flqos  before joining
# Processing line :  there are a few points like dirt displaying exploratory pc movement outlining and acting which energy learners notwithstanding their standard animation courses in  Kolkata  can participate in their  Scholasticism  time to time the learners would likewise agree to accept classes and workshops by looking at changed unmistakable segment specializes in a similar work range they will moreover get the specific preparing or entry level position program to truly feel the genuine occupation condition of their picked work area a few foundations are moreover giving the situating to the students since they have great tie ups with multinational organizations you ought to likewise check for animation course charges in  Kolkata  before joining
# Wiki__Kolkata__flqos
# Wiki__Scholasticism__eqalz
# i hate that i am forced to be a part of a union that thinks this
# seeing as how this is the educational civil rights fight on par with brown v board it makes sense it saddens me that my fellow educators take such a  Wiki__Reactionary__isazzb  stance to what should be a nonpartisan  Wiki__Rights_issue__ibieeif
# Processing line :  seeing as how this is the educational civil rights fight on par with brown v board it makes sense it saddens me that my fellow educators take such a  Reactionary  stance to what should be a nonpartisan  Rights issue
# Wiki__Reactionary__isazzb
# Wiki__Rights_issue__ibieeif
# huge difference between browsing on a computer and drawing on a notebook one can be totally absorbing while the other is just  Wiki__Doodle__qozqa  i can sit there and  Wiki__Doodle__qozqa  and still get something out of a lecture on the other hand if i am browsing  Wiki__Reddit__eazqoos  and reading it takes percent of my attention away from the lecture
# Processing line :  huge difference between browsing on a computer and drawing on a notebook one can be totally absorbing while the other is just  Doodle  i can sit there and  Doodle  and still get something out of a lecture on the other hand if i am browsing  wikiredditeazqoos  and reading it takes percent of my attention away from the lecture
# Wiki__Doodle__qozqa
# wow great offer
# in situations like this i always recommend khan academy
# well uh yeah
# ht s www pincorps com
# i know i am i am doing my student teaching in oklahoma parent lives there and gives me free housing and then im looking for jobs in another state
# is your company for profit nwhat would your company do for high schools
# i have found that in education people often want results right away and often dont want to spend any amount of time building something new a lot of pressure can be put on school leadership because of this and in turn the teachers as well
# the best software training in  Wiki__Kochi__India__sbzlf
# Processing line :  the best software training in  Kochi India
# Wiki__Kochi__India__sbzlf
# you actually make an interesting point to my silly comment  Wiki__Critical_thinking__zlbalz  is not taught in us colleges and universities which i find extremely odd kudos to those students who manage to develop them and its terribly sad that higher learning has become another route for  Wiki__Wage_slavery__selob  student debt i personally do think there is tremendous value in a uni degree but i also hire people who dont have one if they have the requisite skills and ability to think critically and well it can definitely be a rip off in the current environment where many jobs are filed via  Wiki__Nepotism__eiesea  cronyism and other darker means and where real  Wiki__Unemployment__eilfi  is ignored by the government i still believe a uni degree is a necessity but i despair taht it has to come at such a high cost i personally believe it should be free in the best interests of the entire country and with no guarantee that one will actually find decent well paying employment
# Processing line :  you actually make an interesting point to my silly comment  wikicriticalthinkingzlbalz  is not taught in us colleges and universities which i find extremely odd kudos to those students who manage to develop them and its terribly sad that higher learning has become another route for  Wage slavery  student debt i personally do think there is tremendous value in a uni degree but i also hire people who dont have one if they have the requisite skills and ability to think critically and well it can definitely be a rip off in the current environment where many jobs are filed via  Nepotism  cronyism and other darker means and where real  wikiunemploymenteilfi  is ignored by the government i still believe a uni degree is a necessity but i despair taht it has to come at such a high cost i personally believe it should be free in the best interests of the entire country and with no guarantee that one will actually find decent well paying employment
# Wiki__Wage_slavery__selob
# Wiki__Nepotism__eiesea
# thanks for the reply i try to be as simple as possible i am not aimed at complete beginners even i can teach them but thanks for the comment anyway have a good day
# it was mandatory all four years at my hs decades ago however certain other classes or extra curricular activities could get you exempted if you wanted to take something else instead of pe examples marching band or football
# improv comedy seriously
# thanks for sharing of comptia dumps
# the secretary cant change federal law why are you trying to freak people out
# they wont retroactively change these programs in fact they cant only congress can the secretary cannot change federal law and the reason your science friend with a masters degree gets more forgiveness is because there is a shortage of science teachers or at least their was when they passed that provision also you can go for pslf and get the entire remaining balance of your loans forgiven if your a teacher well most can so you may want to redirect the bitter
# heres the  Wiki__YouTube__eszflbb  link ht s www youtube com watch v=ylj wbratn
# Processing line :  heres the  wikiyoutubeeszflbb  link ht s www youtube com watch v=ylj wbratn
# you can and should if you are doing pslf and income driven repayment plan while you are pursuing these programs
# heres a full explanation of the rules www asa org pslf thetes also links to free  Wiki__Web_conferencing__issaeaf  theres a recorded one on  Wiki__YouTube__eszflbb  under the center for  Wiki__Consumer_organization__qeofzo  sorry on mobile so cant link
# Processing line :  heres a full explanation of the rules www asa org pslf thetes also links to free  Web conferencing  theres a recorded one on  wikiyoutubeeszflbb  under the center for  Consumer organization  sorry on mobile so cant link
# Wiki__Web_conferencing__issaeaf
# Wiki__Consumer_organization__qeofzo
# top engineering colleges in up best engineering colleges in mathura top engineering colleges in mathura best engineering colleges in up
# low fee btech colleges in up private engineering colleges in up diploma colleges in up
# so make vouchers only usable at public and publicly funded  Wiki__Charter_school__eeibqe
# Processing line :  so make vouchers only usable at public and publicly funded  Charter school
# Wiki__Charter_school__eeibqe
# two years of average community college  Wiki__Tuition__zfqezo  and two years of average state university  Wiki__Tuition__zfqezo  with no  Wiki__Scholarship__iaoeel  costs dollar k according to the college board  Wiki__Scholarship__iaoeel  work and frugal living would get most kids through school with minimal  Wiki__Student_loan__fbfqqo  those tuition numbers are published tuition and fees not including the generous discounts most students receive off sticker price
# Processing line :  two years of average community college  wikituitionzfqezo  and two years of average state university  wikituitionzfqezo  with no  wikischolarshipiaoeel  costs dollar k according to the college board  wikischolarshipiaoeel  work and frugal living would get most kids through school with minimal  wikistudentloanfbfqqo  those tuition numbers are published tuition and fees not including the generous discounts most students receive off sticker price
# i dont understand the first part of your response are you saying you went to school for more than four years also even if you paid sticker price rare but i suppose it happens were you not working and living frugally while in school
# like you said please educate yourself on investing and fees before putting money in b accounts in particular you do not need the tax advantaged  Wiki__Annuity__financial_contracts___elzfolf  inside a b but variable annuities have huge commissions for  Wiki__Sales__issbqa  funded by huge fees on you so theyre almost exclusively sold in these accounts to unsuspecting teachers max out iras with low cost  Wiki__Index_fund__ioboiz  before touching b accounts
# Processing line :  like you said please educate yourself on investing and fees before putting money in b accounts in particular you do not need the tax advantaged  Annuity financial contracts  inside a b but variable annuities have huge commissions for  Sales  funded by huge fees on you so theyre almost exclusively sold in these accounts to unsuspecting teachers max out iras with low cost  Index fund  before touching b accounts
# Wiki__Annuity__financial_contracts___elzfolf
# Wiki__Sales__issbqa
# Wiki__Index_fund__ioboiz
# the  Wiki__Brown_people__lsiaaaa  cant choose to enroll in other schools with  Wiki__School_choice__zllbi  policies
# Processing line :  the  Brown people  cant choose to enroll in other schools with  School choice  policies
# Wiki__Brown_people__lsiaaaa
# Wiki__School_choice__zllbi
# youre all over the place ive taught in both states indiana is right to work ohio is not i dont know where the personal attacks and ugly  Wiki__Rhetoric__zsffl  is coming from but its unbecoming would you like to discuss why some teachers prefer right to work even if most do not
# Processing line :  youre all over the place ive taught in both states indiana is right to work ohio is not i dont know where the personal attacks and ugly  wikirhetoriczsffl  is coming from but its unbecoming would you like to discuss why some teachers prefer right to work even if most do not
# some teachers prefer right to work states
# thank you for your excellency response
# i think everybody asks themselves this question at least once a life except for our government
# Running document :  2015-04-humanities-students-student-major-majoring-majors_345.txt
# The senior doctor said he had little time left for scientific research after handling a large number of  Wiki__Surgery__fssqq .
# Processing line :  The senior doctor said he had little time left for scientific research after handling a large number of  Surgery .
# Wiki__Surgery__fssqq
# But government rules made it difficult for him to be promoted unless he has articles published in respected  Wiki__Medical_journal__sfiqqz .
# Processing line :  But government rules made it difficult for him to be promoted unless he has articles published in respected  Medical journal .
# Wiki__Medical_journal__sfiqqz
# I sympathize.
# I dont think he made the right choices, but I can see how he could be very easily tempted.
# I was - just this  Wiki__Academic_term__sfssll  - denied promotion at a US liberal arts college.
# Processing line :  I was - just this  wikiacademictermsfssll  - denied promotion at a US liberal arts college.
# The system here is so messed up that it is Monty-Pythonesque.
# Details might give a little insight into what I mean: * Our administration does not promote.
# Wiki__Tenure__eifqsi  are handled entirely by a faculty-appointed committee, called Appointment, Rank, and Tenure, or ART.
# Processing line :  wikitenureeifqsi  are handled entirely by a faculty-appointed committee, called Appointment, Rank, and Tenure, or ART.
# ART essentially looks at three buckets when considering tenure or promotion: teaching and advising, service to the institution and to the profession, and research.
# We are a *very* teaching-centric institution, or claim to be.
# * Our administration has been heavily promoting  Wiki__Undergraduate_education__zilzaq  research.
# Processing line :  * Our administration has been heavily promoting  wikiundergraduateeducationzilzaq  research.
# Understandable: this is a great way to educate students and to get them some real-world experience if done correctly.
# Unfortunately, ART and our admins disagree on which bucket  Wiki__Undergraduate_education__zilzaq  research should be included in.
# Processing line :  Unfortunately, ART and our admins disagree on which bucket  wikiundergraduateeducationzilzaq  research should be included in.
# I have an email from our associate provost telling me that yes, undergraduate research is counted in the research bucket because we take an inclusive view of research.
# ART says no,  Wiki__Undergraduate_education__zilzaq  research is teaching.
# Processing line :  ART says no,  wikiundergraduateeducationzilzaq  research is teaching.
# Of course, ART has a lot fewer opportunities to speechify (our admins push things like this monthly at faculty meetings), and so there is a big disconnect on requirements for tenure and promotion.
# * I get emails several times per week asking me to submit papers to international online journals that expedite the  Wiki__Peer_review__zfiib  process.
# Processing line :  * I get emails several times per week asking me to submit papers to international online journals that expedite the  Peer review  process.
# Wiki__Peer_review__zfiib
# These are pay-to-publish journals, requiring a fee-per-page to publish your paper.
# The review process is laughable, obviously.
# However, I know of colleagues at my institution who publish regularly in these things...and they get  Wiki__Faculty_development__esaqsqq  grants from the institution to cover the publication costs.
# Processing line :  However, I know of colleagues at my institution who publish regularly in these things...and they get  Faculty development  grants from the institution to cover the publication costs.
# Wiki__Faculty_development__esaqsqq
# Yes, thats right - **the institution basically pays a fee to get another faculty publication so we might move higher in the rankings**.
# The faculty who play along get promoted because their research bucket is full.
# * So heres where I am.
# I teach lots of classes and get excellent teaching evaluations from students.
# I developed an  Wiki__Interdisciplinarity__iszoi  minor program that pairs well with many majors in the natural and  Wiki__Social_sciences__zblai , has attracted a good number of students, has been lauded by employers as the reason many of the  Wiki__Social_sciences__zblai  students participating have landed their particular jobs, and were now getting requests from everyone from  Wiki__State_Farm_Insurance__aioasq  Wiki__State_Farm_Insurance__aioasq  to JPL to recommend students from this program.
# Processing line :  I developed an  wikiinterdisciplinarityiszoi  minor program that pairs well with many majors in the natural and  wikisocialscienceszblai , has attracted a good number of students, has been lauded by employers as the reason many of the  wikisocialscienceszblai  students participating have landed their particular jobs, and were now getting requests from everyone from  State Farm Insurance  State Farm Insurance  to JPL to recommend students from this program.
# Wiki__State_Farm_Insurance__aioasq
# I have advised many  Wiki__Undergraduate_education__zilzaq  research projects, and two have earned top honors at the annual national conference in my discipline.
# Processing line :  I have advised many  wikiundergraduateeducationzilzaq  research projects, and two have earned top honors at the annual national conference in my discipline.
# I also chair my department.
# Currently, that means - despite our focus on teaching - hiring a *ton* of adjuncts (about 80% of our student credit units are now taught by adjuncts who dont even hold  Wiki__Working_time__ssziba , despite our claims to being a small  Wiki__Liberal_arts_college__iabiz  where students get to interact with faculty).
# Processing line :  Currently, that means - despite our focus on teaching - hiring a *ton* of adjuncts (about 80% of our student credit units are now taught by adjuncts who dont even hold  wikiworkingtimessziba , despite our claims to being a small  wikiliberalartscollegeiabiz  where students get to interact with faculty).
# Because we have really crappy pay rates for adjuncts and no benefits, we have a pretty high turnover rate and overall poor quality of adjuncts, so I do lots of interviewing, searching for adjuncts, reference calls, etc.
# My discipline is also area that serves the student core credits, and so I do an absolute ton of evaluation of transfer classes, advising for non-majors, interface with other faculty on how to advise freshmen, etc.
# * My letter from ART denying promotion basically described me as a really successful failure.
# They applauded my teaching and service, and refused to promote me because my research was not adequate.
# I do not play the pay-to-publish-in-crappy-journals game.
# I know three other faculty who are in the same situation (and these are just the ones I know about).
# I know of several faculty who were regarded as excellent teachers who were denied tenure because their publication lists were not large enough.
# Meanwhile... * Three doors down the hall from my office is another faculty member,  Wiki__Mikey__film___iboiebqb .
# Processing line :  Meanwhile... * Three doors down the hall from my office is another faculty member,  Mikey film .
# Wiki__Mikey__film___iboiebqb
# Wiki__Mikey__film___iboiebqb  has not shown up to a single committee meeting, faculty meeting, or in any way done any university service for six years.
# Processing line :  Mikey film  has not shown up to a single committee meeting, faculty meeting, or in any way done any university service for six years.
# Wiki__Mikey__film___iboiebqb
# Mikey teaches only MWF classes, and schedules all his  Wiki__Working_time__ssziba  on Wednesday, so that he is on campus Monday and Friday for teaching only, and then 8 hours on Wednesday.
# Processing line :  Mikey teaches only MWF classes, and schedules all his  wikiworkingtimessziba  on Wednesday, so that he is on campus Monday and Friday for teaching only, and then 8 hours on Wednesday.
# Mikey has had sexual relationships with two students, and is currently living with one while she is in a graduate program (this is known to our administrators and, because Mikey is not shy about advertising his personal life through  Wiki__Social_media__saqllfz , so do all the students).
# Processing line :  Mikey has had sexual relationships with two students, and is currently living with one while she is in a graduate program (this is known to our administrators and, because Mikey is not shy about advertising his personal life through  wikisocialmediasaqllfz , so do all the students).
# One year, while having an affair with the first student, Mikey cancelled all his Friday classes...every single one of them.
# Complaints about this led to a new administrative policy concerning the number of absences from the classroom that a faculty member may have.
# Laughably, this policy has never been applied to  Wiki__Mikey__film___iboiebqb .
# Processing line :  Laughably, this policy has never been applied to  Mikey film .
# Wiki__Mikey__film___iboiebqb
# Wiki__Mikey__film___iboiebqb  does publish regularly in whatever journal he can pay to publish his work, so our administrators overlook any indiscretions, and ART promotes him all the way up.
# Processing line :  Mikey film  does publish regularly in whatever journal he can pay to publish his work, so our administrators overlook any indiscretions, and ART promotes him all the way up.
# Wiki__Mikey__film___iboiebqb
# I hear so often that policing publications at the institutional level will take too much time, so ranking systems for institutions focus on quantity and dont police quality overly much, and thus  Wiki__Tenure__eifqsi  processes have to require faculty to do research.
# Processing line :  I hear so often that policing publications at the institutional level will take too much time, so ranking systems for institutions focus on quantity and dont police quality overly much, and thus  wikitenureeifqsi  processes have to require faculty to do research.
# **Bullshit**.
# This assumes that publications have to play a large role in ranking institutions.
# This assumes that the only kind of institution we can aspire to be is one that has a big focus on research at the expense of teaching and advising students.
# This assumes that every faculty member has to contribute to the published research pile.
# There is a lot more I could say about this, but I think Im about done venting for now.

# %% [markdown]
# # Cluster Words 1
# Implementing clustering using distance as cosine similarity

# %%
from nltk.cluster import KMeansClusterer
import nltk
import numpy as np 
from copy import deepcopy
from sklearn import cluster
from sklearn import metrics

all_tensors = []
all_words = []
for it in selected_word_vectors:
	all_words.append(deepcopy(it[1]))
	all_tensors.append(deepcopy(it[2]))

NO_OF_ITERATIONS = 15
NUM_OF_CLUSTERS = 2

kclusterer = KMeansClusterer(NUM_OF_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=NO_OF_ITERATIONS)
assigned_clusters = kclusterer.cluster(all_tensors, assign_clusters=True)


new_list = []
for x in range(NUM_OF_CLUSTERS):
  new_list.append([])

for index, word in enumerate(all_words):    
    new_list[assigned_clusters[index]].append(str(word))
	
for i,l in enumerate(new_list):
  print("Cluster {}:\n".format(i))
  print(l,"\n")
# Out:
# Cluster 0:
#
# ['Wiki__Photo_shoot__ioeqbbal', 'Wiki__Wikipedia__sofelef', 'Wiki__Marxism__iqofose', 'Wiki__Fascism__iiosf', 'Wiki__Ideology__lsfbq', 'Wiki__Fascism__iiosf', 'Wiki__Capitalism__sfib', 'Wiki__Fascism__iiosf', 'Wiki__Capitalism__sfib', 'Wiki__Fascism__iiosf', 'Wiki__Capitalism__sfib', 'Wiki__Capitalism__sfib', 'Wiki__Capitalism__sfib', 'Wiki__Capitalism__sfib', 'Wiki__Socialism__zbafl', 'Wiki__Democracy__lqsq', 'Wiki__Democracy__lqsq', 'Wiki__Democracy__lqsq', 'Wiki__Nationalism__zilfa', 'Wiki__Nationalism__zilfa', 'Wiki__Propaganda__zezoe', 'Wiki__Propaganda__zezoe', 'Wiki__Representative_democracy__szeia', 'Wiki__Direct_democracy__qsaib', 'Wiki__Sexual_minority__esazbsf', 'Wiki__Learning_disability__ioqlooaz', 'Wiki__Executive_system__laefls', 'Wiki__Silicon_Valley__zbqlb']
#
# Cluster 1:
#
# ['Wiki__Idiot__isoof', 'Wiki__Facebook__lszqela', 'Wiki__Barack_Obama__sefebb', 'Wiki__Shit__eazzi', 'Wiki__Fuck__sslslzz', 'Wiki__Sarcasm__zqsaql', 'Wiki__Russia__zseqi', 'Wiki__Russia__zseqi', 'Wiki__LOL__zaaelq', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Wiki__ezasi', 'Wiki__Far_right__zzizzo', 'Wiki__Algebra__ieqa', 'Wiki__Algebra__ieqa', 'Wiki__United_States__efeflso', 'Wiki__Physical_fitness__fezqab', 'Wiki__California__sfol', 'Wiki__Scientific_method__zbaee', 'Wiki__Unemployment__eilfi', 'Wiki__Educational_toy__iboiblb', 'Wiki__Disability__sbzas', 'Wiki__Disability__sbzas', 'Wiki__Real_point__aoaaqeq', 'Wiki__Single_parent__zzbioq', 'Wiki__Rights_issue__ibieeif', 'Wiki__Reddit__eazqoos', 'Wiki__Critical_thinking__zlbalz', 'Wiki__Unemployment__eilfi', 'Wiki__Wage_slavery__selob', 'Wiki__YouTube__eszflbb', 'Wiki__YouTube__eszflbb', 'Wiki__Consumer_organization__qeofzo', 'Wiki__Charter_school__eeibqe', 'Wiki__Tuition__zfqezo', 'Wiki__Tuition__zfqezo', 'Wiki__Scholarship__iaoeel', 'Wiki__Scholarship__iaoeel', 'Wiki__Student_loan__fbfqqo', 'Wiki__Sales__issbqa', 'Wiki__Index_fund__ioboiz', 'Wiki__Brown_people__lsiaaaa', 'Wiki__School_choice__zllbi', 'Wiki__Rhetoric__zsffl', 'Wiki__Surgery__fssqq', 'Wiki__Medical_journal__sfiqqz', 'Wiki__Academic_term__sfssll', 'Wiki__Tenure__eifqsi', 'Wiki__Undergraduate_education__zilzaq', 'Wiki__Undergraduate_education__zilzaq', 'Wiki__Undergraduate_education__zilzaq', 'Wiki__Peer_review__zfiib', 'Wiki__Faculty_development__esaqsqq', 'Wiki__Interdisciplinarity__iszoi', 'Wiki__Social_sciences__zblai', 'Wiki__Social_sciences__zblai', 'Wiki__State_Farm_Insurance__aioasq', 'Wiki__State_Farm_Insurance__aioasq', 'Wiki__Undergraduate_education__zilzaq', 'Wiki__Working_time__ssziba', 'Wiki__Liberal_arts_college__iabiz', 'Wiki__Working_time__ssziba', 'Wiki__Social_media__saqllfz', 'Wiki__Tenure__eifqsi']

# %% [markdown]
# # Cluster the words - 2
# Implementing clustering using eucledian distance.

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import KDTree
from copy import deepcopy


NO_OF_ITERATIONS = 20
NUM_OF_CLUSTERS = 5

all_tensors = []
all_words = []
for it in selected_word_vectors:
  all_words.append(it[1])
  all_tensors.append(it[2].data.numpy())


def clustering_on_wordvecs(word_vectors, num_clusters):
    # Initalize a k-means object and use it to extract centroids
    kmeans_clustering = KMeans(n_clusters = num_clusters, init='k-means++', n_init=NO_OF_ITERATIONS);
    idx = kmeans_clustering.fit_predict(word_vectors);
    
    return kmeans_clustering.cluster_centers_, idx;

import time
start = time.time();
centers, clusters = clustering_on_wordvecs(all_tensors, NUM_OF_CLUSTERS);
print('Total time: ' + str((time.time() - start)) + ' secs')

start = time.time();
centroid_map = dict(zip(all_words, clusters));
print('Total time: ' + str((time.time() - start)) + ' secs')

rev_map = {}
for key in centroid_map:
  if centroid_map[key] not in rev_map:
    rev_map[centroid_map[key]] = [key]
  else:
    rev_map[centroid_map[key]].append(key)

final_csv_data = []
for i, word_vec in enumerate(selected_word_vectors):
  final_csv_data.append([word_vec[0], word_vec[1], clusters[i]])


for key in rev_map:
  print(rev_map[key])
# Out:
# Total time: 0.22172927856445312 secs
# Total time: 0.0001373291015625 secs
# ['Wiki__Idiot__isoof', 'Wiki__Facebook__lszqela', 'Wiki__Barack_Obama__sefebb', 'Wiki__Russia__zseqi', 'Wiki__Wikipedia__sofelef', 'Wiki__Wiki__ezasi', 'Wiki__United_States__efeflso', 'Wiki__California__sfol', 'Wiki__Unemployment__eilfi', 'Wiki__Reddit__eazqoos', 'Wiki__Tuition__zfqezo', 'Wiki__Scholarship__iaoeel', 'Wiki__Tenure__eifqsi', 'Wiki__Undergraduate_education__zilzaq', 'Wiki__Interdisciplinarity__iszoi', 'Wiki__Social_sciences__zblai', 'Wiki__Working_time__ssziba', 'Wiki__Social_media__saqllfz']
# ['Wiki__Photo_shoot__ioeqbbal', 'Wiki__Scientific_method__zbaee', 'Wiki__Educational_toy__iboiblb', 'Wiki__Executive_system__laefls', 'Wiki__Silicon_Valley__zbqlb', 'Wiki__Real_point__aoaaqeq', 'Wiki__Single_parent__zzbioq', 'Wiki__Rights_issue__ibieeif', 'Wiki__Wage_slavery__selob', 'Wiki__Consumer_organization__qeofzo', 'Wiki__Charter_school__eeibqe', 'Wiki__Sales__issbqa', 'Wiki__Index_fund__ioboiz', 'Wiki__Brown_people__lsiaaaa', 'Wiki__School_choice__zllbi', 'Wiki__Medical_journal__sfiqqz', 'Wiki__Peer_review__zfiib', 'Wiki__Faculty_development__esaqsqq', 'Wiki__State_Farm_Insurance__aioasq']
# ['Wiki__Shit__eazzi', 'Wiki__Fuck__sslslzz', 'Wiki__Sarcasm__zqsaql', 'Wiki__LOL__zaaelq', 'Wiki__Blog__eebfs', 'Wiki__Troll__Internet___ifsqf', 'Wiki__Algebra__ieqa', 'Wiki__YouTube__eszflbb', 'Wiki__Student_loan__fbfqqo', 'Wiki__Rhetoric__zsffl', 'Wiki__Surgery__fssqq', 'Wiki__Academic_term__sfssll', 'Wiki__Liberal_arts_college__iabiz']
# ['Wiki__Marxism__iqofose', 'Wiki__Fascism__iiosf', 'Wiki__Ideology__lsfbq', 'Wiki__Capitalism__sfib', 'Wiki__Socialism__zbafl', 'Wiki__Democracy__lqsq', 'Wiki__Far_right__zzizzo', 'Wiki__Nationalism__zilfa', 'Wiki__Propaganda__zezoe', 'Wiki__Representative_democracy__szeia', 'Wiki__Direct_democracy__qsaib']
# ['Wiki__Sexual_minority__esazbsf', 'Wiki__Physical_fitness__fezqab', 'Wiki__Learning_disability__ioqlooaz', 'Wiki__Disability__sbzas', 'Wiki__Critical_thinking__zlbalz']

# %% [markdown]
# # Develop CSV

# %% [markdown]
# Exporting the result output to a csv.

# %%
# CSV 1 row : doc_name, word, cluster_id
import csv

with open(os.path.join(save_dir, output_file_name), "w") as f:
    writer = csv.writer(f)
    writer.writerows(final_csv_data)
